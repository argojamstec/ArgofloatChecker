# %% [markdown]
# # JAMSTEC DB スキーム確認ツール for APEX(APF11)

# %%
import os
import pandas as pd
import re
import termcolor
import Levenshtein # レーベンシュタイン距離ライブラリにある、ジャロ・ウインクラー距離を計算するのに使う
# jaro_dist = Levenshtein.jaro_winkler(srt1 , str2)

apf11_excel = pd.read_excel('Apex_apf11.xlsx' , sheet_name=None) # sheet_name=Noneで全てのシート読み込む

# %% [markdown]
# ### ジャロ・ウィンクラー距離法の関数
#
# 2つの文字列を移動したり修正したりした回数等で計算する。１で一致とみなされる。
#
# Winkler, W. E. (1990). "String Comparator Metrics and Enhanced Decision Rules in the Fellegi-Sunter Model of Record Linkage". Proceedings of the Section on Survey Research Methods. American Statistical Association: 354–359.

# %%
def jaro_dist(str1,str2):
    return Levenshtein.jaro_winkler(str1,str2)

# %%
print(apf11_excel['scheme'].columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %% [markdown]
# ### エクセルファイルの列を数えて抜き出す

# %%
msgcol = apf11_excel['scheme'].iloc[:,1]
a26msg = apf11_excel['scheme'].iloc[:,7] # ７列目がA26のmsg , 8列目はlog 以降同様に数える
x1a27system = apf11_excel['scheme'].iloc[:,10]
x2x3a28a29system = apf11_excel['scheme'].iloc[:,12]
a30a31x4system = apf11_excel['scheme'].iloc[:,14]
a33a34a35system = apf11_excel['scheme'].iloc[:,16]

scheme = pd.concat([msgcol,a26msg,x1a27system,x2x3a28a29system,a30a31x4system,a33a34a35system], axis=1)\
.rename(columns={'Unnamed: 1':'field_name', 'Unnamed: 7':'a26msg' , 'Unnamed: 10':'x1a27system' , 'Unnamed: 12':'x2x3a28a29system' , 'Unnamed: 14':'a30a31x4system' , 'Unnamed: 16':'a33a34a35system'})

techcol = apf11_excel['tech'].iloc[:,1]
a26msg = apf11_excel['tech'].iloc[:,7]
a26log = apf11_excel['tech'].iloc[:,8]
x1a27science = apf11_excel['tech'].iloc[:,9]
x1a27vitals = apf11_excel['tech'].iloc[:,10]
x1a27systemtech = apf11_excel['tech'].iloc[:,11]
x2x3a28a29a30a31a33a34science = apf11_excel['tech'].iloc[:,12]
x2x3a28a29a30a31a33a34vitals = apf11_excel['tech'].iloc[:,13]
x2x3a28a29a30a31a33a34systemtech = apf11_excel['tech'].iloc[:,14]
a28science = apf11_excel['tech'].iloc[:,15]
a28vitals = apf11_excel['tech'].iloc[:,16]
a28system = apf11_excel['tech'].iloc[:,17]

tech = pd.concat([techcol,a26msg,a26log,x1a27science,x1a27vitals,x1a27systemtech,x2x3a28a29a30a31a33a34science,x2x3a28a29a30a31a33a34vitals,x2x3a28a29a30a31a33a34systemtech,a28science,a28vitals,a28system], axis=1)\
.rename(columns={'Unnamed: 1':'field_name'\
                 , 'Unnamed: 7':'a26msg' , 'Unnamed: 8':'a26log'\
                 , 'Unnamed: 9':'x1a27sicence' , 'Unnamed: 10':'x1a27vitals' , 'Unnamed: 11':'x1a27system'\
                 , 'Unnamed: 12':'x2x3a28a29a30a31a33a34science' , 'Unnamed: 13':'x2x3a28a29a30a31a33a34vitals' , 'Unnamed: 14':'x2x3a28a29a30a31a33a34system'\
                 , 'Unnamed: 15':'a28science' , 'Unnamed: 16':'a28vitals' , 'Unnamed: 17':'a28system'})

# %% [markdown]
# ### 生データ読み込み

# %%
with open('rawdata/A34/f8900.001.20200310T174432.system_log.txt','r') as sys:
    sysline = sys.readlines()
    
with open('rawdata/A34/f8900.001.20200310T174432.vitals_log.csv','r') as vit:
    vitline = vit.readlines()
    
with open('rawdata/A34/f8900.001.merge.science_log.csv','r') as sci:
    sciline = sci.readlines()

# %% [markdown]
# ### system_log読み込み
# 各行末をパラメータ名と判断する
#
# 後ろからみて｜があったらそこまでをパラメータと判断する

# %%
regex = r'|$'
pt = re.compile(regex)

reg2 = r'^[A-Z]'
pt2 = re.compile(reg2)

sysdata = {}
i = 0
for line in sysline:
    if(pt.match(line)):
        param = str(line.split('|')[-1:])
        # 前と後ろの邪魔な文字を削除
        para = param[2:]
        para2 = para[:-4]
        # 数字は削除する,先頭のみ取得
        para3 = str(para2.split(' ')[0])
        if(pt2.match(para3)):
            sysdata[i] = para3
            i += 1

#print(sysdata)
sysdf = pd.DataFrame(sysdata.values() , columns={'field_name'})
#print(sysdf)

# %% [markdown]
# ### science_log 読み込み
# CTD_P/CTD_PTS/CTD_CPと数値があるのみなので比較する必要なし

# %% [markdown]
# ### vitals_log 読み込み
#
# vitals_coreがカンマ区切りなのでそのまま読み取る。
# カラム数が重要（５項目めがBatteryVoltage等と決まる
#
# ###### Excel の内容判断は文章化されていて困難なのでテーブルとして以下を予め設定する（２０２０１０最新のA34が基準）
# |Column|DB table name|
# | ---- | ---- |
# |3|AirBladderPressure|
# |5|voltage_load<br>QuiescentVolts<br>Sbe41cpVolts<br>BuoyancyPumpVolts<br>BuoyancyPumpVolts2<br>AirPumpVolts|
# |7|Humidity|
# |8|LeakDetectVolts|
# |9|Vacuum|
# |11|CoulmbCounterAmphrs|

# %%
regex = r'^VITALS' # VITALS_COREの行は取得する
pattern = re.compile(regex)
vitdata = []

for line in vitline:
    if(pattern.match(line)):
        vitdata.append(line.split(','))
        print(line.split(','))
# Out:
# ['VITALS_CORE', '20200308T014341', '11.709', '2352', '15.311', '3484', '9.859', '2.324', '7.410', '2914', '2175.462', '53.910', '-690\n']
# ['VITALS_CORE', '20200308T014345', '11.765', '2363', '15.302', '3482', '9.830', '2.324', '7.420', '2907', '2175.462', '35.393', '-453\n']
# ['VITALS_CORE', '20200308T024715', '7.697', '1573', '15.420', '3509', '10.993', '2.319', '8.006', '3138', '2217.097', '31.799', '-407\n']
# ['VITALS_CORE', '20200310T072607', '7.300', '1494', '15.372', '3498', '10.440', '2.303', '7.588', '2986', '2239.063', '30.861', '-395\n']
# ['VITALS_CORE', '20200310T104227', '7.285', '1491', '15.328', '3489', '10.382', '2.301', '7.583', '2978', '2249.657', '31.408', '-402\n']
# ['VITALS_CORE', '20200310T173723', '7.652', '1562', '15.021', '3417', '9.161', '2.321', '7.947', '3122', '2520.428', '31.174', '-399\n']
# ['VITALS_CORE', '20200310T174429', '11.938', '2402', '14.915', '3393', '8.579', '2.304', '7.122', '2797', '2533.866', '52.269', '-669\n']

# %%
# 以下のような感じで数値が入ってたら項目ありと判断するだけ。
print((vitdata[0][4]))
# Out:
# 15.311

# %%
print(scheme['a33a34a35system'])
# Out:
# 0                     NaN
# 1              system_log
# 2            ParkPressure
# 3     DeepDescentPressure
# 4         DownTime+UpTime
#              ...
# 61                    NaN
# 62                    NaN
# 63                    NaN
# 64                    NaN
# 65                    NaN
# Name: a33a34a35system, Length: 66, dtype: object

# %%
print(sysdf['field_name'][37:])
# Out:
# 37       PreludeSelfTest
# 38           PreludeTime
# 39       SurfacePressure
# 40         TelemetryDays
# 41     TelemetryInterval
#              ...
# 466                  Set
# 467                  GPS
# 468                  GPS
# 469                  GPS
# 470                 Time
# Name: field_name, Length: 434, dtype: object

# %%
# 結果保存用のDFを準備
resultdf = pd.DataFrame(columns=['index','msg','xls','score'])

for line in sysdf['field_name']:
    query = scheme['a33a34a35system'].str.startswith(line , na=False)
    #print(query.values)
    if (query[query == True].first_valid_index()):
        print( termcolor.colored(line + ' field exists.','blue'))
    else:
        print( termcolor.colored(line + ' is not found.' , 'red'))
        
        for index,item in scheme.iterrows():
            score = jaro_dist(line , str(item['a33a34a35system']) ) # 引数を入れ替えると結果が多少変わる。
            #print(line + ' is probably ' + str(item['a33a34a35system']) + ' ( ' + str(round(score,2)*100) + '%)' )
            record = pd.Series([index , line , item['a33a34a35system'] , score] , index=resultdf.columns)
            resultdf = resultdf.append(record , ignore_index=True)
# Out:
# Archived: is not found.
# Archived: is not found.
# Archived: is not found.
# PRELUDE is not found.
# Starting is not found.
# ActivateRecoveryMode is not found.
# AscentRate field exists.
# AscentStartTimes field exists.
# AscentTimeout field exists.
# AscentTimerInterval is not found.
# BuoyancyNudge field exists.
# DeepDescentCount field exists.
# DeepDescentPressure field exists.
# DeepDescentTimeout field exists.
# DeepDescentTimerInterval is not found.
# DeepProfileFirst field exists.
# DownTime field exists.
# EmergencyTimerInterval is not found.
# HyperRetractCount field exists.
# HyperRetractPressure field exists.
# IceMonths field exists.
# IdleTimerInterval field exists.
# InitialBuoyancyNudge field exists.
# LeakDetect is not found.
# LogVerbosity field exists.
# MActivationCount is not found.
# MActivationPressure is not found.
# MinBuoyancyCount field exists.
# MinVacuum is not found.
# ParkBuoyancyNudge field exists.
# ParkDeadBand field exists.
# ParkDescentCount field exists.
# ParkDescentTimeout field exists.
# ParkDescentTimerInterval is not found.
# ParkPressure field exists.
# ParkTimerInterval is not found.
# PnPCycleLen field exists.
# PreludeSelfTest is not found.
# PreludeTime is not found.
# SurfacePressure field exists.
# TelemetryDays is not found.
# TelemetryInterval is not found.
# TelemetryTimeout is not found.
# UpTime field exists.
# VitalsMask is not found.
# Checksum is not found.
# SAMPLE is not found.
# SAMPLE is not found.
# SAMPLE is not found.
# PROFILE is not found.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkPressure field exists.
# PARKDESCENT is not found.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# ParkDescentCount field exists.
# PARK is not found.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# DeepDescentPressure field exists.
# DEEPDESCENT is not found.
# CP is not found.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# CP is not found.
# Empty is not found.
# SurfacePressure field exists.
# ASCENT is not found.
# Adjusting is not found.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Buoyancy field exists.
# Air is not found.
# Found is not found.
# Completing is not found.
# WatchDog is not found.
# Set is not found.
# GPS is not found.
# GPS is not found.
# GPS is not found.
# Time is not found.

# %%
print(resultdf)
# Out:
#      index        msg                  xls     score
# 0        0  Archived:                  NaN  0.000000
# 1        1  Archived:           system_log  0.403704
# 2        2  Archived:         ParkPressure  0.462963
# 3        3  Archived:  DeepDescentPressure  0.275828
# 4        4  Archived:      DownTime+UpTime  0.451852
# ...    ...        ...                  ...       ...
# 6925    61       Time                  NaN  0.000000
# 6926    62       Time                  NaN  0.000000
# 6927    63       Time                  NaN  0.000000
# 6928    64       Time                  NaN  0.000000
# 6929    65       Time                  NaN  0.000000
#
# [6930 rows x 4 columns]

# %% [markdown]
# ### ソートして上位３件を表示

# %%
items = len(scheme.dropna()) # Index数、この数分ジャロ・ウインクラー距離を計算したら次のマッチしなかった語句になる
kazu = int( len(resultdf) / items ) # クエリーのリストになくnot foundで表示した数

for count in range(kazu):
    res = resultdf[items*count : items*(count+1)]
    msgrank = res.sort_values('score',ascending=False)[:3] # Score降順にソートして上から3つを表示

    if((re.match('^.',msgrank.iat[0,1])) is not None  ):
        # print(ranking.iat[0,3])
        # score が０と１の時は抜く（アルゴリズム？で１００％が結構出てる。
        disp_rank = str(msgrank.iat[0,1]) + ' is probably ' + str(msgrank.iat[0,2]) + ' ( ' + str(round(msgrank.iat[0,3] , 2) * 100 ) + '% )' + '\n' \
        + ' or ' + str(msgrank.iat[1,2]) + ' ( ' + str(round(msgrank.iat[1,3] , 2) * 100 ) + '% )' + '\n' \
        + ' or ' + str(msgrank.iat[2,2]) + ' ( ' + str(round(msgrank.iat[2,3] , 2) * 100 ) + '% )' + '\n' 
    
        print( disp_rank )
# Out:
# Archived: is probably UpTime ( 52.0% )
#  or SurfacePressure ( 51.0% )
#  or DownTime ( 49.0% )
#
# Archived: is probably AscentStartTimes ( 56.00000000000001% )
#  or AscentStartTimes ( 56.00000000000001% )
#  or AscentStartTimes ( 56.00000000000001% )
#
# Archived: is probably AscentRate ( 59.0% )
#  or AscentTimeout ( 55.00000000000001% )
#  or PnPCycleLen ( 47.0% )
#
# Archived: is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Archived: is probably SurfacePressure ( 51.0% )
#  or ParkPressure ( 46.0% )
#  or DownTime+UpTime ( 45.0% )
#
# Archived: is probably AscentStartTimes ( 56.00000000000001% )
#  or AscentStartTimes ( 56.00000000000001% )
#  or AscentStartTimes ( 56.00000000000001% )
#
# Archived: is probably AscentRate ( 59.0% )
#  or AscentTimeout ( 55.00000000000001% )
#  or ParkDeadBand ( 53.0% )
#
# Archived: is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Archived: is probably SurfacePressure ( 51.0% )
#  or ParkPressure ( 46.0% )
#  or DownTime+UpTime ( 45.0% )
#
# Archived: is probably AscentStartTimes ( 56.00000000000001% )
#  or AscentStartTimes ( 56.00000000000001% )
#  or AscentStartTimes ( 56.00000000000001% )
#
# Archived: is probably AscentRate ( 59.0% )
#  or AscentTimeout ( 55.00000000000001% )
#  or ParkDeadBand ( 53.0% )
#
# Archived: is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# PRELUDE is probably ParkPressure ( 47.0% )
#  or DeepDescentPressure ( 40.0% )
#  or nan ( 0.0% )
#
# PRELUDE is probably HyperRetractCount ( 40.0% )
#  or HyperRetractPressure ( 40.0% )
#  or nan ( 0.0% )
#
# PRELUDE is probably ParkDeadBand ( 54.0% )
#  or ParkDescentCount ( 52.0% )
#  or ParkDescentTimeout ( 52.0% )
#
# PRELUDE is probably LogVerbosity ( 41.0% )
#  or AscentRate ( 0.0% )
#  or nan ( 0.0% )
#
# Starting is probably nan ( 49.0% )
#  or nan ( 49.0% )
#  or nan ( 49.0% )
#
# Starting is probably nan ( 49.0% )
#  or nan ( 49.0% )
#  or nan ( 49.0% )
#
# Starting is probably ParkDeadBand ( 54.0% )
#  or ParkDescentCount ( 52.0% )
#  or ParkBuoyancyNudge ( 52.0% )
#
# Starting is probably BuoyancyNudge ( 54.0% )
#  or nan ( 49.0% )
#  or nan ( 49.0% )
#
# Starting is probably nan ( 49.0% )
#  or nan ( 49.0% )
#  or nan ( 49.0% )
#
# ActivateRecoveryMode is probably HyperRetractPressure ( 52.0% )
#  or HyperRetractCount ( 49.0% )
#  or system_log ( 48.0% )
#
# ActivateRecoveryMode is probably AscentStartTimes ( 57.99999999999999% )
#  or AscentStartTimes ( 57.99999999999999% )
#  or AscentStartTimes ( 57.99999999999999% )
#
# ActivateRecoveryMode is probably AscentRate ( 67.0% )
#  or AscentTimeout ( 59.0% )
#  or TelemetryRetryInterval ( 48.0% )
#
# AscentTimerInterval is probably DeepDescentPressure ( 50.0% )
#  or nan ( 46.0% )
#  or system_log ( 45.0% )
#
# AscentTimerInterval is probably DownTime ( 46.0% )
#  or nan ( 46.0% )
#  or nan ( 46.0% )
#
# AscentTimerInterval is probably AscentStartTimes ( 88.0% )
#  or AscentStartTimes ( 88.0% )
#  or AscentStartTimes ( 88.0% )
#
# AscentTimerInterval is probably AscentTimeout ( 100.0% )
#  or AscentRate ( 88.0% )
#  or TelemetryRetryInterval ( 67.0% )
#
# AscentTimerInterval is probably IceMonths ( 55.00000000000001% )
#  or nan ( 46.0% )
#  or nan ( 46.0% )
#
# DeepDescentTimerInterval is probably DeepDescentPressure ( 100.0% )
#  or DownTime+UpTime ( 53.0% )
#  or DownTime ( 50.0% )
#
# DeepDescentTimerInterval is probably DeepProfileFirst ( 73.0% )
#  or ParkDescentTimeout ( 60.0% )
#  or ParkDescentCount ( 59.0% )
#
# DeepDescentTimerInterval is probably DeepDescentCount ( 100.0% )
#  or DeepDescentTimeout ( 100.0% )
#  or TelemetryRetryInterval ( 68.0% )
#
# DeepDescentTimerInterval is probably IceMonths ( 41.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# EmergencyTimerInterval is probably DeepDescentPressure ( 48.0% )
#  or DownTime+UpTime ( 48.0% )
#  or UpTime ( 47.0% )
#
# EmergencyTimerInterval is probably IdleTimerInterval[sec]+PreludeTime[min] ( 55.00000000000001% )
#  or AscentStartTimes ( 51.0% )
#  or AscentStartTimes ( 51.0% )
#
# EmergencyTimerInterval is probably TelemetryRetryInterval ( 70.0% )
#  or DeepDescentTimeout ( 55.00000000000001% )
#  or DeepProfileFirst ( 54.0% )
#
# EmergencyTimerInterval is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# LeakDetect is probably DeepDescentPressure ( 50.0% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# LeakDetect is probably HyperRetractCount ( 60.0% )
#  or HyperRetractPressure ( 57.99999999999999% )
#  or ParkDescentCount ( 55.00000000000001% )
#
# LeakDetect is probably LogVerbosity ( 56.99999999999999% )
#  or AscentRate ( 53.0% )
#  or DeepDescentCount ( 52.0% )
#
# LeakDetect is probably TelemetryRetryInterval ( 51.0% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# LeakDetect is probably nan ( 48.0% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# MActivationCount is probably HyperRetractCount ( 56.99999999999999% )
#  or AscentStartTimes ( 54.0% )
#  or AscentStartTimes ( 54.0% )
#
# MActivationCount is probably MinBuoyancyCount ( 72.0% )
#  or AscentRate ( 60.0% )
#  or AscentTimeout ( 60.0% )
#
# MActivationCount is probably TelemetryRetryInterval ( 48.0% )
#  or IceMonths ( 46.0% )
#  or nan ( 0.0% )
#
# MActivationPressure is probably SurfacePressure ( 65.0% )
#  or DeepDescentPressure ( 55.00000000000001% )
#  or system_log ( 44.0% )
#
# MActivationPressure is probably AscentStartTimes ( 62.0% )
#  or AscentStartTimes ( 62.0% )
#  or HyperRetractPressure ( 57.99999999999999% )
#
# MActivationPressure is probably AscentStartTimes ( 62.0% )
#  or AscentStartTimes ( 62.0% )
#  or AscentTimeout ( 59.0% )
#
# MActivationPressure is probably AscentRate ( 64.0% )
#  or IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 42.0% )
#
# MinVacuum is probably nan ( 48.0% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# MinVacuum is probably nan ( 48.0% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# MinVacuum is probably MinBuoyancyCount ( 72.0% )
#  or ParkDescentTimeout ( 50.0% )
#  or nan ( 48.0% )
#
# MinVacuum is probably BuoyancyNudge ( 55.00000000000001% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# ParkDescentTimerInterval is probably ParkPressure ( 78.0% )
#  or DeepDescentPressure ( 54.0% )
#  or nan ( 48.0% )
#
# ParkDescentTimerInterval is probably SurfacePressure ( 57.99999999999999% )
#  or HyperRetractPressure ( 55.00000000000001% )
#  or HyperRetractCount ( 49.0% )
#
# ParkDescentTimerInterval is probably ParkDescentTimeout ( 100.0% )
#  or ParkDescentCount ( 100.0% )
#  or ParkDeadBand ( 85.0% )
#
# ParkDescentTimerInterval is probably TelemetryRetryInterval ( 69.0% )
#  or AscentTimeout ( 57.99999999999999% )
#  or nan ( 46.0% )
#
# ParkTimerInterval is probably ParkPressure ( 78.0% )
#  or DeepDescentPressure ( 50.0% )
#  or nan ( 46.0% )
#
# ParkTimerInterval is probably UpTime ( 63.0% )
#  or DownTime ( 57.99999999999999% )
#  or SurfacePressure ( 55.00000000000001% )
#
# ParkTimerInterval is probably ParkDescentTimeout ( 79.0% )
#  or ParkDeadBand ( 77.0% )
#  or ParkDescentCount ( 76.0% )
#
# ParkTimerInterval is probably TelemetryRetryInterval ( 67.0% )
#  or AscentTimeout ( 51.0% )
#  or AscentRate ( 49.0% )
#
# ParkTimerInterval is probably IceMonths ( 50.0% )
#  or nan ( 46.0% )
#  or nan ( 46.0% )
#
# PreludeSelfTest is probably ParkPressure ( 60.0% )
#  or SurfacePressure ( 56.99999999999999% )
#  or DeepDescentPressure ( 52.0% )
#
# PreludeSelfTest is probably ParkDescentTimeout ( 60.0% )
#  or DeepProfileFirst ( 59.0% )
#  or ParkDescentCount ( 57.99999999999999% )
#
# PreludeSelfTest is probably DeepDescentTimeout ( 55.00000000000001% )
#  or DeepDescentCount ( 54.0% )
#  or PnPCycleLen ( 51.0% )
#
# PreludeSelfTest is probably IceMonths ( 45.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# PreludeTime is probably ParkPressure ( 66.0% )
#  or SurfacePressure ( 50.0% )
#  or DeepDescentPressure ( 48.0% )
#
# PreludeTime is probably ParkDescentTimeout ( 75.0% )
#  or ParkDeadBand ( 61.0% )
#  or AscentStartTimes ( 59.0% )
#
# PreludeTime is probably DeepProfileFirst ( 55.00000000000001% )
#  or PnPCycleLen ( 54.0% )
#  or DeepDescentTimeout ( 52.0% )
#
# PreludeTime is probably IceMonths ( 40.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# TelemetryDays is probably DeepDescentPressure ( 52.0% )
#  or system_log ( 44.0% )
#  or system_log ( 44.0% )
#
# TelemetryDays is probably IdleTimerInterval[sec]+PreludeTime[min] ( 57.99999999999999% )
#  or HyperRetractPressure ( 51.0% )
#  or AscentStartTimes ( 50.0% )
#
# TelemetryDays is probably ParkBuoyancyNudge ( 51.0% )
#  or DeepProfileFirst ( 50.0% )
#  or DeepDescentCount ( 50.0% )
#
# TelemetryDays is probably TelemetryRetryInterval ( 97.0% )
#  or IceMonths ( 52.0% )
#  or nan ( 0.0% )
#
# TelemetryInterval is probably DeepDescentPressure ( 55.00000000000001% )
#  or DownTime+UpTime ( 44.0% )
#  or system_log ( 42.0% )
#
# TelemetryInterval is probably IdleTimerInterval[sec]+PreludeTime[min] ( 60.0% )
#  or HyperRetractPressure ( 53.0% )
#  or HyperRetractCount ( 52.0% )
#
# TelemetryInterval is probably DeepDescentCount ( 54.0% )
#  or ParkDescentTimeout ( 51.0% )
#  or DeepDescentTimeout ( 51.0% )
#
# TelemetryInterval is probably TelemetryRetryInterval ( 99.0% )
#  or IceMonths ( 39.0% )
#  or nan ( 0.0% )
#
# TelemetryTimeout is probably DownTime+UpTime ( 56.00000000000001% )
#  or DeepDescentPressure ( 53.0% )
#  or system_log ( 50.0% )
#
# TelemetryTimeout is probably AscentStartTimes ( 54.0% )
#  or AscentStartTimes ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 51.0% )
#
# TelemetryTimeout is probably ParkDescentTimeout ( 71.0% )
#  or DeepDescentTimeout ( 69.0% )
#  or AscentTimeout ( 64.0% )
#
# TelemetryTimeout is probably TelemetryRetryInterval ( 97.0% )
#  or LogVerbosity ( 49.0% )
#  or IceMonths ( 45.0% )
#
# VitalsMask is probably ParkPressure ( 52.0% )
#  or SurfacePressure ( 50.0% )
#  or nan ( 48.0% )
#
# VitalsMask is probably nan ( 48.0% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# VitalsMask is probably InitialBuoyancyNudge ( 57.99999999999999% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# VitalsMask is probably nan ( 48.0% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# Checksum is probably ParkPressure ( 53.0% )
#  or nan ( 48.0% )
#  or nan ( 48.0% )
#
# Checksum is probably system_log ( 45.0% )
#  or DownTime ( 42.0% )
#  or HyperRetractCount ( 39.0% )
#
# Checksum is probably PnPCycleLen ( 48.0% )
#  or ParkBuoyancyNudge ( 46.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 43.0% )
#
# Checksum is probably AscentTimeout ( 52.0% )
#  or LogVerbosity ( 47.0% )
#  or BuoyancyNudge ( 47.0% )
#
# Checksum is probably IceMonths ( 46.0% )
#  or ParkPressure ( 42.0% )
#  or nan ( 0.0% )
#
# SAMPLE is probably SurfacePressure ( 47.0% )
#  or DownTime+UpTime ( 0.0% )
#  or nan ( 0.0% )
#
# SAMPLE is probably PnPCycleLen ( 42.0% )
#  or ParkDeadBand ( 42.0% )
#  or AscentStartTimes ( 41.0% )
#
# SAMPLE is probably AscentRate ( 42.0% )
#  or AscentTimeout ( 41.0% )
#  or MinBuoyancyCount ( 41.0% )
#
# SAMPLE is probably IceMonths ( 43.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# SAMPLE is probably SurfacePressure ( 47.0% )
#  or ParkPressure ( 42.0% )
#  or DeepDescentPressure ( 0.0% )
#
# SAMPLE is probably ParkDeadBand ( 42.0% )
#  or AscentStartTimes ( 41.0% )
#  or AscentStartTimes ( 41.0% )
#
# SAMPLE is probably AscentRate ( 42.0% )
#  or PnPCycleLen ( 42.0% )
#  or AscentTimeout ( 41.0% )
#
# SAMPLE is probably IceMonths ( 43.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# SAMPLE is probably SurfacePressure ( 47.0% )
#  or ParkPressure ( 42.0% )
#  or nan ( 0.0% )
#
# SAMPLE is probably ParkDeadBand ( 42.0% )
#  or AscentStartTimes ( 41.0% )
#  or AscentStartTimes ( 41.0% )
#
# SAMPLE is probably AscentRate ( 42.0% )
#  or PnPCycleLen ( 42.0% )
#  or AscentTimeout ( 41.0% )
#
# SAMPLE is probably IceMonths ( 43.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# PROFILE is probably ParkPressure ( 47.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# PROFILE is probably ParkDescentCount ( 46.0% )
#  or ParkDescentTimeout ( 46.0% )
#  or HyperRetractCount ( 40.0% )
#
# PROFILE is probably PnPCycleLen ( 54.0% )
#  or ParkDeadBand ( 47.0% )
#  or ParkBuoyancyNudge ( 46.0% )
#
# PROFILE is probably IceMonths ( 42.0% )
#  or nan ( 0.0% )
#  or TelemetryRetryInterval ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# PARKDESCENT is probably ParkPressure ( 45.0% )
#  or DownTime+UpTime ( 44.0% )
#  or SurfacePressure ( 39.0% )
#
# PARKDESCENT is probably AscentStartTimes ( 49.0% )
#  or AscentStartTimes ( 49.0% )
#  or HyperRetractCount ( 43.0% )
#
# PARKDESCENT is probably ParkDescentCount ( 54.0% )
#  or ParkDescentTimeout ( 53.0% )
#  or PnPCycleLen ( 51.0% )
#
# PARKDESCENT is probably AscentRate ( 46.0% )
#  or LogVerbosity ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 47.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentRate ( 57.99999999999999% )
#  or IceMonths ( 44.0% )
#  or LogVerbosity ( 42.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 47.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentRate ( 57.99999999999999% )
#  or IceMonths ( 44.0% )
#  or LogVerbosity ( 42.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 47.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# PARK is probably ParkPressure ( 50.0% )
#  or IceMonths ( 44.0% )
#  or nan ( 0.0% )
#
# PARK is probably nan ( 0.0% )
#  or SurfacePressure ( 0.0% )
#  or nan ( 0.0% )
#
# PARK is probably PnPCycleLen ( 50.0% )
#  or ParkDeadBand ( 50.0% )
#  or ParkDescentCount ( 49.0% )
#
# PARK is probably AscentRate ( 45.0% )
#  or AscentTimeout ( 44.0% )
#  or MinBuoyancyCount ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or DeepDescentPressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# DEEPDESCENT is probably DownTime+UpTime ( 49.0% )
#  or DeepDescentPressure ( 49.0% )
#  or DownTime ( 46.0% )
#
# DEEPDESCENT is probably DeepProfileFirst ( 49.0% )
#  or AscentStartTimes ( 44.0% )
#  or AscentStartTimes ( 44.0% )
#
# DEEPDESCENT is probably DeepDescentCount ( 54.0% )
#  or DeepDescentTimeout ( 53.0% )
#  or PnPCycleLen ( 45.0% )
#
# DEEPDESCENT is probably nan ( 0.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# CP is probably ParkPressure ( 53.0% )
#  or nan ( 0.0% )
#  or system_log ( 0.0% )
#
# CP is probably ParkDeadBand ( 53.0% )
#  or ParkDescentCount ( 52.0% )
#  or ParkBuoyancyNudge ( 52.0% )
#
# CP is probably PnPCycleLen ( 53.0% )
#  or nan ( 0.0% )
#  or DeepProfileFirst ( 0.0% )
#
# CP is probably nan ( 0.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentRate ( 57.99999999999999% )
#  or IceMonths ( 44.0% )
#  or LogVerbosity ( 42.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 47.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentRate ( 57.99999999999999% )
#  or IceMonths ( 44.0% )
#  or LogVerbosity ( 42.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 47.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentRate ( 57.99999999999999% )
#  or IceMonths ( 44.0% )
#  or LogVerbosity ( 42.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 47.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentRate ( 57.99999999999999% )
#  or IceMonths ( 44.0% )
#  or LogVerbosity ( 42.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 47.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentRate ( 57.99999999999999% )
#  or IceMonths ( 44.0% )
#  or LogVerbosity ( 42.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IdleTimerInterval[sec]+PreludeTime[min] ( 47.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or IceMonths ( 44.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or UpTime ( 43.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or TelemetryRetryInterval ( 39.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or ParkPressure ( 40.0% )
#  or SurfacePressure ( 39.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentRate ( 57.99999999999999% )
#  or IceMonths ( 44.0% )
#  or LogVerbosity ( 42.0% )
#
# CP is probably ParkPressure ( 53.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# CP is probably nan ( 0.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# CP is probably PnPCycleLen ( 53.0% )
#  or ParkDeadBand ( 53.0% )
#  or ParkDescentCount ( 52.0% )
#
# CP is probably BuoyancyNudge ( 0.0% )
#  or AscentTimeout ( 0.0% )
#  or AscentRate ( 0.0% )
#
# Empty is probably DeepDescentPressure ( 42.0% )
#  or system_log ( 37.0% )
#  or nan ( 0.0% )
#
# Empty is probably UpTime ( 41.0% )
#  or system_log ( 37.0% )
#  or HyperRetractCount ( 34.0% )
#
# Empty is probably PnPCycleLen ( 43.0% )
#  or AscentStartTimes ( 42.0% )
#  or AscentStartTimes ( 42.0% )
#
# Empty is probably TelemetryRetryInterval ( 50.0% )
#  or AscentRate ( 43.0% )
#  or BuoyancyNudge ( 43.0% )
#
# Empty is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# ASCENT is probably UpTime ( 44.0% )
#  or DownTime ( 43.0% )
#  or DownTime+UpTime ( 41.0% )
#
# ASCENT is probably AscentStartTimes ( 47.0% )
#  or AscentStartTimes ( 47.0% )
#  or AscentStartTimes ( 47.0% )
#
# ASCENT is probably AscentTimeout ( 55.00000000000001% )
#  or AscentRate ( 48.0% )
#  or DeepDescentTimeout ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Adjusting is probably system_log ( 54.0% )
#  or UpTime ( 43.0% )
#  or ParkPressure ( 40.0% )
#
# Adjusting is probably AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#  or AscentStartTimes ( 53.0% )
#
# Adjusting is probably AscentTimeout ( 59.0% )
#  or AscentRate ( 57.99999999999999% )
#  or BuoyancyNudge ( 52.0% )
#
# Adjusting is probably IceMonths ( 44.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Air is probably UpTime ( 50.0% )
#  or ParkPressure ( 47.0% )
#  or SurfacePressure ( 47.0% )
#
# Air is probably AscentStartTimes ( 52.0% )
#  or AscentStartTimes ( 52.0% )
#  or AscentStartTimes ( 52.0% )
#
# Air is probably AscentRate ( 53.0% )
#  or AscentTimeout ( 52.0% )
#  or MinBuoyancyCount ( 47.0% )
#
# Air is probably nan ( 0.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Found is probably nan ( 51.0% )
#  or DownTime+UpTime ( 51.0% )
#  or nan ( 51.0% )
#
# Found is probably DownTime ( 55.00000000000001% )
#  or nan ( 51.0% )
#  or nan ( 51.0% )
#
# Found is probably nan ( 51.0% )
#  or nan ( 51.0% )
#  or nan ( 51.0% )
#
# Found is probably IceMonths ( 54.0% )
#  or nan ( 51.0% )
#  or nan ( 51.0% )
#
# Completing is probably system_log ( 53.0% )
#  or system_log ( 53.0% )
#  or nan ( 51.0% )
#
# Completing is probably DownTime ( 51.0% )
#  or HyperRetractCount ( 49.0% )
#  or UpTime ( 49.0% )
#
# Completing is probably PnPCycleLen ( 59.0% )
#  or BuoyancyNudge ( 51.0% )
#  or LogVerbosity ( 49.0% )
#
# Completing is probably IceMonths ( 45.0% )
#  or TelemetryRetryInterval ( 44.0% )
#  or nan ( 0.0% )
#
# WatchDog is probably system_log ( 56.00000000000001% )
#  or nan ( 49.0% )
#  or nan ( 49.0% )
#
# WatchDog is probably system_log ( 56.00000000000001% )
#  or nan ( 49.0% )
#  or nan ( 49.0% )
#
# WatchDog is probably nan ( 49.0% )
#  or nan ( 49.0% )
#  or BuoyancyNudge ( 48.0% )
#
# WatchDog is probably nan ( 49.0% )
#  or nan ( 49.0% )
#  or nan ( 49.0% )
#
# Set is probably SurfacePressure ( 52.0% )
#  or nan ( 49.0% )
#  or nan ( 49.0% )
#
# Set is probably system_log ( 48.0% )
#  or HyperRetractCount ( 46.0% )
#  or HyperRetractPressure ( 46.0% )
#
# Set is probably AscentStartTimes ( 47.0% )
#  or AscentStartTimes ( 47.0% )
#  or AscentStartTimes ( 47.0% )
#
# Set is probably AscentRate ( 48.0% )
#  or AscentTimeout ( 47.0% )
#  or TelemetryRetryInterval ( 46.0% )
#
# Set is probably IceMonths ( 48.0% )
#  or ParkPressure ( 47.0% )
#  or nan ( 0.0% )
#
# GPS is probably SurfacePressure ( 47.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# GPS is probably PnPCycleLen ( 47.0% )
#  or ParkDeadBand ( 47.0% )
#  or ParkDescentCount ( 47.0% )
#
# GPS is probably MinBuoyancyCount ( 0.0% )
#  or nan ( 0.0% )
#  or BuoyancyNudge ( 0.0% )
#
# GPS is probably ParkPressure ( 47.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# GPS is probably SurfacePressure ( 47.0% )
#  or DownTime+UpTime ( 0.0% )
#  or nan ( 0.0% )
#
# GPS is probably PnPCycleLen ( 47.0% )
#  or ParkDeadBand ( 47.0% )
#  or ParkDescentCount ( 47.0% )
#
# GPS is probably DeepDescentTimeout ( 0.0% )
#  or InitialBuoyancyNudge ( 0.0% )
#  or MinBuoyancyCount ( 0.0% )
#
# GPS is probably nan ( 0.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# GPS is probably ParkPressure ( 47.0% )
#  or SurfacePressure ( 47.0% )
#  or DeepDescentPressure ( 0.0% )
#
# GPS is probably ParkDeadBand ( 47.0% )
#  or ParkDescentCount ( 47.0% )
#  or ParkBuoyancyNudge ( 46.0% )
#
# GPS is probably PnPCycleLen ( 47.0% )
#  or DeepDescentCount ( 0.0% )
#  or DeepDescentTimeout ( 0.0% )
#
# GPS is probably nan ( 0.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
#
# Time is probably UpTime ( 89.0% )
#  or system_log ( 45.0% )
#  or system_log ( 45.0% )
#
# Time is probably ParkDeadBand ( 44.0% )
#  or AscentStartTimes ( 44.0% )
#  or AscentStartTimes ( 44.0% )
#
# Time is probably TelemetryRetryInterval ( 56.99999999999999% )
#  or AscentRate ( 45.0% )
#  or LogVerbosity ( 44.0% )
#
# Time is probably IceMonths ( 45.0% )
#  or nan ( 0.0% )
#  or nan ( 0.0% )
