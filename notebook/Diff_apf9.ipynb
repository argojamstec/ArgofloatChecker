# %% [markdown]
# # JAMSTEC DBスキーム確認ツールfor Apex(APF9)
#
# Excelファイルを読んでフロートの生データと比較して既に登録用のテーブル・フィールドがあるかどうかを確認する。
#
# フロート生データ（テキスト）はメーカー提供ツールにより変換する

# %%
import os
import pandas as pd
import re
import termcolor
import Levenshtein # レーベンシュタイン距離ライブラリにある、ジャロ・ウインクラー距離を計算するのに使う
# jaro_dist = Levenshtein.jaro_winkler(srt1 , str2)

apf9_excel = pd.read_excel('Apex_apf9.xlsx' , sheet_name=None) # sheet_name=Noneで全てのシート読み込む

# %% [markdown]
# ## ジャロ・ウィンクラー距離法の関数
#
# ２つの文字列の類似度を返す。１で完全一致
#
# #### Winkler, W. E. (1990). "String Comparator Metrics and Enhanced Decision Rules in the Fellegi-Sunter Model of Record Linkage". Proceedings of the Section on Survey Research Methods. American Statistical Association: 354–359.

# %%
def jaro_dist(str1,str2):
    return Levenshtein.jaro_winkler(str1,str2)

# %%
print(apf9_excel['tech'].columns)
# Out:
# Index(['Unnamed: 0',
#        '■：DBに新規定義する項目　■：DBに定義しない項目　■：データがあり、DB列がない項目　■：データがなく、DB列がある項目　■：次回のプロファイルで挿入',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %% [markdown]
# ### エクセルファイルの列は目視で確認して抜き出す
# エクセルファイルが更新されたら変更必要

# %%
msgcol = apf9_excel['scheme'].iloc[:,1]
a19msg = apf9_excel['scheme'].iloc[:,7] # ７列目がA19のmsg , 8列目はlog 以降同様に数える
a21msg = apf9_excel['scheme'].iloc[:,9]
a25msg = apf9_excel['scheme'].iloc[:,11]
a26msg = apf9_excel['scheme'].iloc[:,13]

scheme = pd.concat([msgcol,a19msg,a21msg,a25msg,a26msg], axis=1)\
.rename(columns={'■：DBに新規定義する項目　■：DBに定義しない項目　■：データがあり、DB列がない項目　■：データがなく、DB列がある項目':'field_name'\
                 , 'Unnamed: 7':'a19' , 'Unnamed: 9':'a21' , 'Unnamed: 11':'a25' , 'Unnamed: 13':'a26'})

techcol = apf9_excel['tech'].iloc[:,1]
a19msgtech = apf9_excel['tech'].iloc[:,7]
a19logtech = apf9_excel['tech'].iloc[:,8]
a21msgtech = apf9_excel['tech'].iloc[:,9]
a21logtech = apf9_excel['tech'].iloc[:,10]
a25msgtech = apf9_excel['tech'].iloc[:,11]
a25logtech = apf9_excel['tech'].iloc[:,12]
a26msgtech = apf9_excel['tech'].iloc[:,13]
a26logtech = apf9_excel['tech'].iloc[:,14]

tech = pd.concat([techcol,a19msgtech,a19logtech,a21msgtech,a21logtech,a25msgtech,a25logtech,a26msgtech,a26logtech], axis=1)\
.rename(columns={'■：DBに新規定義する項目　■：DBに定義しない項目　■：データがあり、DB列がない項目　■：データがなく、DB列がある項目　■：次回のプロファイルで挿入':'field_name'\
                 , 'Unnamed: 7':'a19msg' , 'Unnamed: 8':'a19log' , 'Unnamed: 9':'a21msg' , 'Unnamed: 10':'a21log' , 'Unnamed: 11':'a25msg' , 'Unnamed: 12':'a25log' , 'Unnamed: 13':'a26msg' , 'Unnamed: 14':'a26log' })

# %% [markdown]
# ### テキスト生データ読み込み
#
# バイナリからの変換はメーカー提供ツールによる

# %%
with open('rawdata/A26/2695.001.msg','r') as msg:
    msgline = msg.readlines()
    
with open('rawdata/A26/2695.001.log','r') as log:
    logline = log.readlines()

# %% [markdown]
# ###  msgファイル変換

# %%
# msgline,loglineとも1行毎に読み込んでる。
# 安直にループさせて新しいDataFrameを作ることは出来ないので辞書リストに一度保存する（Pythonの仕様）
msgdata = {}
i = 0
for orig_msg in msgline:
    regex = r'^\$' # 先頭が＄ならその行をパラメータと判断する
    regex2 = r'^[A-Z]' # 先頭が大文字アルファベットの場合もパラメータと判断
    pattern = re.compile(regex)
    pattern2 = re.compile(regex2)

    # 行頭$スペースの2文字を除いて（の手前までをパラメータとして保存
    if (pattern.match(orig_msg) ): # ’(’以降は削除
        pos = orig_msg.find('(')
        #print(orig_msg[2:pos])
        msgdata[i] =  (orig_msg[2:pos])
        i += 1
    elif (pattern2.match(orig_msg)): # 先頭大文字、＝までもパラメータとする
        pos = orig_msg.find('=')
        #print(orig_msg[:pos])
        msgdata[i] =  orig_msg[:pos]
        i += 1

# dict_valuesをPythonの listに変換する必要はなかった。
#print(data.values())
msgdf = pd.DataFrame(msgdata.values() , columns={'field_name'})
#print(msgdf)
# Out:
#                           field_name
# 0    Mission configuration for Apf9i
# 1                      AscentTimeOut
# 2                          AtDialCmd
# 3                         AltDialCmd
# 4                      BuoyancyNudge
# ..                               ...
# 110                     Sbe41cpVolts
# 111                    Sbe41cpStatus
# 112            SurfacePistonPosition
# 113                  SurfacePressure
# 114                           Vacuum
#
# [115 rows x 1 columns]

# %% [markdown]
# ### logファイル変換

# %%
logdata = {}
i  = 0

for orig_log in logline:
# sec)が見えたらその次の文字列をパラメータとみなす
    pos = orig_log.find('sec) ')
    pos2 = orig_log.find('()')
    #print(orig_log[pos+5:pos2].split(' ')[0])
    logdata[i] = orig_log[pos+5:pos2].split(' ')[0]
    i += 1

logdf = pd.DataFrame(logdata.values(),columns={'field_name'})
#print(logdf)
#print(type(logdata))

# %% [markdown]
# ### 比較する
#
# #### msgファイルとスキーマ情報タブの比較

# %%
# 結果保存用のDFを準備
msgdf = pd.DataFrame(columns=['index','msg','xls','score'])

for line in msgdata.values():
    #print(line)
    query = scheme['a26'].str.startswith(line , na=False)
    #print(query.values)
    if (query[query == True].first_valid_index()):
        print( termcolor.colored(line + ' field exists.','blue'))
    else:
        print( termcolor.colored(line + ' is not found.' , 'red'))
        
        for index,item in scheme.iterrows():
            score = jaro_dist(str(item['a26']) , line) # 引数を入れ替えると結果が多少変わる。
            #print(line + ' is probably ' + str(item['i4']) + ' ( ' + str(round(score,2)*100) + '%)' )
            record = pd.Series([index , line , item['a26'] , score] , index=msgdf.columns)
            msgdf = msgdf.append(record , ignore_index=True)
# Out:
# Mission configuration for Apf9i is not found.
# AscentTimeOut field exists.
# AtDialCmd field exists.
# AltDialCmd field exists.
# BuoyancyNudge field exists.
# BuoyancyNudgeInitial field exists.
# ConnectTimeOut field exists.
# CpActivationP field exists.
# DeepProfileDescentTime field exists.
# DeepProfilePistonPos field exists.
# DeepProfilePressure is not found.
# DownTime field exists.
# FloatId is not found.
# FullExtension field exists.
# FullRetraction field exists.
# IceDetectionP field exists.
# IceEvasionP field exists.
# IceMLTCritical field exists.
# IceMonths field exists.
# MaxAirBladder is not found.
# MaxLogKb field exists.
# MissionPrelude field exists.
# OkVacuum field exists.
# PActivationPistonPosition field exists.
# ParkDescentTime field exists.
# ParkPistonPos field exists.
# ParkPressure is not found.
# PnPCycleLen field exists.
# RafosWindowN is not found.
# TelemetryRetry field exists.
# TimeOfDay field exists.
# UpTime field exists.
# Verbosity field exists.
# DebugBits is not found.
#  field exists.
# ParkPts:    Jun 25 2017 14:59:58  1498402798   18034 1155.01  3.0146 34.3871 is not found.
# Profile 2695.001 terminated: Sun Jun 25 23:41:23 2017 is not found.
# Discrete samples: 2 is not found.
#       p        t        s is not found.
# Fix:  170.176  38.648 06/25/2017 235520    8 is not found.
# Apf9iFwRev is not found.
# ActiveBallastAdjustments is not found.
# AirBladderPressure is not found.
# AirPumpAmps is not found.
# AirPumpVolts is not found.
# BuoyancyPumpOnTime is not found.
# BuoyancyPumpAmps is not found.
# BuoyancyPumpVolts is not found.
# IceEvasionRecord is not found.
# IceMLMedianT is not found.
# IceMLSample is not found.
# CurrentPistonPosition is not found.
# DeepProfilePistonPosition is not found.
# GpsFixTime is not found.
# FlashErrorsCorrectable is not found.
# FlashErrorsUncorrectable is not found.
# FloatId is not found.
# ParkDescentPCnt is not found.
# ParkDescentP[0] is not found.
# ParkDescentP[1] is not found.
# ParkDescentP[2] is not found.
# ParkDescentP[3] is not found.
# ParkDescentP[4] is not found.
# ParkDescentP[5] is not found.
# ParkPistonPosition is not found.
# ParkObs is not found.
# ProfileId is not found.
# ObsIndex is not found.
# QuiescentAmps is not found.
# QuiescentVolts is not found.
# RtcSkew is not found.
# Sbe41cpAmps is not found.
# Sbe41cpVolts is not found.
# Sbe41cpStatus is not found.
# SurfacePistonPosition is not found.
# SurfacePressure is not found.
# Vacuum is not found.
# Fix:  170.174  38.652 06/26/2017 001700    9 is not found.
# Apf9iFwRev is not found.
# ActiveBallastAdjustments is not found.
# AirBladderPressure is not found.
# AirPumpAmps is not found.
# AirPumpVolts is not found.
# BuoyancyPumpOnTime is not found.
# BuoyancyPumpAmps is not found.
# BuoyancyPumpVolts is not found.
# IceEvasionRecord is not found.
# IceMLMedianT is not found.
# IceMLSample is not found.
# CurrentPistonPosition is not found.
# DeepProfilePistonPosition is not found.
# GpsFixTime is not found.
# FlashErrorsCorrectable is not found.
# FlashErrorsUncorrectable is not found.
# FloatId is not found.
# ParkDescentPCnt is not found.
# ParkDescentP[0] is not found.
# ParkDescentP[1] is not found.
# ParkDescentP[2] is not found.
# ParkDescentP[3] is not found.
# ParkDescentP[4] is not found.
# ParkDescentP[5] is not found.
# ParkPistonPosition is not found.
# ParkObs is not found.
# ProfileId is not found.
# ObsIndex is not found.
# QuiescentAmps is not found.
# QuiescentVolts is not found.
# RtcSkew is not found.
# Sbe41cpAmps is not found.
# Sbe41cpVolts is not found.
# Sbe41cpStatus is not found.
# SurfacePistonPosition is not found.
# SurfacePressure is not found.
# Vacuum is not found.

# %%
# Out:
#      index                              msg             xls     score
# 0        0  Mission configuration for Apf9i             NaN  0.000000
# 1        1  Mission configuration for Apf9i             A26  0.000000
# 2        2  Mission configuration for Apf9i             msg  0.455197
# 3        3  Mission configuration for Apf9i             NaN  0.000000
# 4        4  Mission configuration for Apf9i             NaN  0.000000
# ...    ...                              ...             ...       ...
# 3388    34                           Vacuum  IceMLTCritical  0.412698
# 3389    35                           Vacuum       IceMonths  0.425926
# 3390    36                           Vacuum             NaN  0.500000
# 3391    37                           Vacuum      FlashErase  0.422222
# 3392    38                           Vacuum     FlashCreate  0.419192
#
# [3393 rows x 4 columns]

# %% [markdown]
# ## ソートして上位3件を表示

# %%
items = len(scheme.dropna()) # Index数、この数分ジャロ・ウインクラー距離を計算したら次のマッチしなかった語句になる
kazu = int( len(msgdf) / items ) # クエリーのリストになくnot foundで表示した数

for count in range(kazu):
    res = msgdf[items*count : items*(count+1)]
    msgrank = res.sort_values('score',ascending=False)[:3] # Score降順にソートして上から3つを表示

    if((re.match('^.',msgrank.iat[0,1])) is not None  ):
        # print(ranking.iat[0,3])
        # score が０と１の時は抜く（アルゴリズム？で１００％が結構出てる。
        disp_rank = str(msgrank.iat[0,1]) + ' is probably ' + str(msgrank.iat[0,2]) + ' ( ' + str(round(msgrank.iat[0,3] , 2) * 100 ) + '% )' + '\n' \
        + ' or ' + str(msgrank.iat[1,2]) + ' ( ' + str(round(msgrank.iat[1,3] , 2) * 100 ) + '% )' + '\n' \
        + ' or ' + str(msgrank.iat[2,2]) + ' ( ' + str(round(msgrank.iat[2,3] , 2) * 100 ) + '% )' + '\n' 
    
        print( disp_rank )
# Out:
# Mission configuration for Apf9i is probably MissionPrelude ( 88.0% )
#  or PActivationPistonPosition ( 56.00000000000001% )
#  or ParkPistonPos ( 52.0% )
#
# DeepProfilePressure is probably DeepProfilePistonPos ( 100.0% )
#  or DownTime ( 56.00000000000001% )
#  or ParkPistonPos ( 54.0% )
#
# DeepProfilePressure is probably DeepProfileDescentTime ( 100.0% )
#  or Verbosity ( 55.00000000000001% )
#  or IceDetectionP ( 54.0% )
#
# FloatId is probably FullExtension ( 60.0% )
#  or FullRetraction ( 59.0% )
#  or BuoyancyNudge ( 55.00000000000001% )
#
# FloatId is probably FlashErase ( 66.0% )
#  or FlashCreate ( 65.0% )
#  or AtDialCmd ( 59.0% )
#
# MaxAirBladder is probably AirBladderMaxP ( 71.0% )
#  or MaxLogKb ( 67.0% )
#  or MissionPrelude ( 59.0% )
#
# ParkPressure is probably ParkPistonPos ( 85.0% )
#  or ParkDescentTime ( 81.0% )
#  or MissionPrelude ( 57.99999999999999% )
#
# ParkPressure is probably PnPCycleLen ( 61.0% )
#  or FlashCreate ( 52.0% )
#  or PActivationPistonPosition ( 51.0% )
#
# RafosWindowN is probably ParkPistonPos ( 60.0% )
#  or Verbosity ( 53.0% )
#  or MissionPrelude ( 52.0% )
#
# DebugBits is probably DeepProfilePistonPos ( 64.0% )
#  or DownTime ( 54.0% )
#  or IceEvasionP ( 52.0% )
#
# DebugBits is probably DeepProfileDescentTime ( 63.0% )
#  or Verbosity ( 60.0% )
#  or IceMonths ( 56.00000000000001% )
#
# ParkPts:    Jun 25 2017 14:59:58  1498402798   18034 1155.01  3.0146 34.3871 is probably ParkPistonPos ( 77.0% )
#  or ParkDescentTime ( 67.0% )
#  or PnPCycleLen ( 49.0% )
#
# Profile 2695.001 terminated: Sun Jun 25 23:41:23 2017 is probably DownTime ( 48.0% )
#  or UpTime ( 46.0% )
#  or nan ( 45.0% )
#
# Profile 2695.001 terminated: Sun Jun 25 23:41:23 2017 is probably PnPCycleLen ( 50.0% )
#  or ParkDescentTime ( 47.0% )
#  or PActivationPistonPosition ( 47.0% )
#
# Discrete samples: 2 is probably DeepProfilePistonPos ( 62.0% )
#  or ParkDescentTime ( 56.00000000000001% )
#  or DownTime ( 56.00000000000001% )
#
# Discrete samples: 2 is probably IceMonths ( 55.00000000000001% )
#  or IceMLTCritical ( 55.00000000000001% )
#  or FlashCreate ( 54.0% )
#
#       p        t        s is probably CpActivationP ( 41.0% )
#  or PActivationPistonPosition ( 39.0% )
#  or IceDetectionP ( 37.0% )
#
# Fix:  170.176  38.648 06/25/2017 235520    8 is probably FullExtension ( 46.0% )
#  or FullRetraction ( 43.0% )
#  or UpTime ( 40.0% )
#
# Apf9iFwRev is probably UpTime ( 60.0% )
#  or A26 ( 53.0% )
#  or DownTime ( 45.0% )
#
# Apf9iFwRev is probably AirBladderMaxP ( 55.00000000000001% )
#  or DeepProfilePistonPos ( 53.0% )
#  or DeepProfileDescentTime ( 53.0% )
#
# ActiveBallastAdjustments is probably AirBladderMaxP ( 57.99999999999999% )
#  or AscentTimeOut ( 54.0% )
#  or A26 ( 51.0% )
#
# ActiveBallastAdjustments is probably AltDialCmd ( 66.0% )
#  or AtDialCmd ( 63.0% )
#  or CpActivationP ( 61.0% )
#
# AirBladderPressure is probably AirBladderMaxP ( 100.0% )
#  or AtDialCmd ( 59.0% )
#  or AltDialCmd ( 56.99999999999999% )
#
# AirPumpAmps is probably AirBladderMaxP ( 65.0% )
#  or AscentTimeOut ( 55.00000000000001% )
#  or A26 ( 53.0% )
#
# AirPumpAmps is probably AtDialCmd ( 57.99999999999999% )
#  or AltDialCmd ( 56.99999999999999% )
#  or TimeOfDay ( 47.0% )
#
# AirPumpVolts is probably AirBladderMaxP ( 68.0% )
#  or AtDialCmd ( 56.00000000000001% )
#  or DeepProfilePistonPos ( 55.00000000000001% )
#
# AirPumpVolts is probably AltDialCmd ( 55.00000000000001% )
#  or OkVacuum ( 53.0% )
#  or IceMonths ( 53.0% )
#
# BuoyancyPumpOnTime is probably BuoyancyNudge ( 95.0% )
#  or BuoyancyNudgeInitial ( 94.0% )
#  or ConnectTimeOut ( 60.0% )
#
# BuoyancyPumpAmps is probably BuoyancyNudge ( 95.0% )
#  or BuoyancyNudgeInitial ( 93.0% )
#  or OkVacuum ( 55.00000000000001% )
#
# BuoyancyPumpVolts is probably DownTime ( 52.0% )
#  or ParkPistonPos ( 49.0% )
#  or ConnectTimeOut ( 49.0% )
#
# BuoyancyPumpVolts is probably BuoyancyNudge ( 95.0% )
#  or BuoyancyNudgeInitial ( 94.0% )
#  or OkVacuum ( 54.0% )
#
# IceEvasionRecord is probably ParkPistonPos ( 56.00000000000001% )
#  or MissionPrelude ( 54.0% )
#  or FullRetraction ( 52.0% )
#
# IceEvasionRecord is probably IceEvasionP ( 100.0% )
#  or IceDetectionP ( 72.0% )
#  or IceMLTCritical ( 72.0% )
#
# IceMLMedianT is probably PnPCycleLen ( 62.0% )
#  or CpActivationP ( 55.00000000000001% )
#  or AscentTimeOut ( 54.0% )
#
# IceMLMedianT is probably IceMLTCritical ( 84.0% )
#  or IceMonths ( 79.0% )
#  or IceDetectionP ( 76.0% )
#
# IceMLSample is probably IceMLTCritical ( 86.0% )
#  or IceMonths ( 76.0% )
#  or IceEvasionP ( 70.0% )
#
# CurrentPistonPosition is probably PActivationPistonPosition ( 65.0% )
#  or ParkPistonPos ( 63.0% )
#  or DeepProfilePistonPos ( 62.0% )
#
# DeepProfilePistonPosition is probably DeepProfilePistonPos ( 100.0% )
#  or ParkPistonPos ( 66.0% )
#  or ConnectTimeOut ( 56.00000000000001% )
#
# DeepProfilePistonPosition is probably DeepProfileDescentTime ( 100.0% )
#  or PActivationPistonPosition ( 64.0% )
#  or IceDetectionP ( 54.0% )
#
# GpsFixTime is probably AscentTimeOut ( 56.00000000000001% )
#  or DownTime ( 55.00000000000001% )
#  or UpTime ( 51.0% )
#
# GpsFixTime is probably CpActivationP ( 51.0% )
#  or AtDialCmd ( 47.0% )
#  or ParkPistonPos ( 47.0% )
#
# FlashErrorsCorrectable is probably FullRetraction ( 54.0% )
#  or FullExtension ( 52.0% )
#  or ParkDescentTime ( 50.0% )
#
# FlashErrorsCorrectable is probably FlashErase ( 92.0% )
#  or FlashCreate ( 83.0% )
#  or BuoyancyNudgeInitial ( 54.0% )
#
# FlashErrorsUncorrectable is probably FlashErase ( 91.0% )
#  or FlashCreate ( 80.0% )
#  or nan ( 49.0% )
#
# FloatId is probably FullExtension ( 60.0% )
#  or FullRetraction ( 59.0% )
#  or AtDialCmd ( 59.0% )
#
# ParkDescentPCnt is probably ParkDescentTime ( 100.0% )
#  or ParkPistonPos ( 79.0% )
#  or FlashErase ( 66.0% )
#
# ParkDescentPCnt is probably IceDetectionP ( 59.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#  or PActivationPistonPosition ( 56.99999999999999% )
#
# ParkDescentP[0] is probably ParkDescentTime ( 100.0% )
#  or ParkPistonPos ( 79.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#
# ParkDescentP[1] is probably ParkPistonPos ( 79.0% )
#  or IceDetectionP ( 56.99999999999999% )
#  or IceEvasionP ( 56.99999999999999% )
#
# ParkDescentP[1] is probably ParkDescentTime ( 100.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#  or IceDetectionP ( 56.99999999999999% )
#
# ParkDescentP[2] is probably ParkDescentTime ( 100.0% )
#  or ParkPistonPos ( 79.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#
# ParkDescentP[3] is probably ParkPistonPos ( 79.0% )
#  or IceDetectionP ( 56.99999999999999% )
#  or IceEvasionP ( 56.99999999999999% )
#
# ParkDescentP[3] is probably ParkDescentTime ( 100.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#  or IceDetectionP ( 56.99999999999999% )
#
# ParkDescentP[4] is probably ParkDescentTime ( 100.0% )
#  or ParkPistonPos ( 79.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#
# ParkDescentP[5] is probably ParkPistonPos ( 79.0% )
#  or IceDetectionP ( 56.99999999999999% )
#  or IceEvasionP ( 56.99999999999999% )
#
# ParkDescentP[5] is probably ParkDescentTime ( 100.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#  or IceDetectionP ( 56.99999999999999% )
#
# ParkPistonPosition is probably ParkPistonPos ( 100.0% )
#  or ParkDescentTime ( 76.0% )
#  or DeepProfilePistonPos ( 66.0% )
#
# ParkPistonPosition is probably PActivationPistonPosition ( 75.0% )
#  or CpActivationP ( 54.0% )
#  or PnPCycleLen ( 53.0% )
#
# ParkObs is probably ParkPistonPos ( 82.0% )
#  or ParkDescentTime ( 81.0% )
#  or Verbosity ( 59.0% )
#
# ProfileId is probably DownTime ( 56.99999999999999% )
#  or ParkPistonPos ( 56.99999999999999% )
#  or ParkDescentTime ( 56.00000000000001% )
#
# ProfileId is probably PnPCycleLen ( 57.99999999999999% )
#  or AtDialCmd ( 56.00000000000001% )
#  or MissionPrelude ( 50.0% )
#
# ObsIndex is probably MissionPrelude ( 53.0% )
#  or DownTime ( 50.0% )
#  or Verbosity ( 49.0% )
#
# QuiescentAmps is probably AscentTimeOut ( 57.99999999999999% )
#  or ParkPistonPos ( 52.0% )
#  or UpTime ( 50.0% )
#
# QuiescentAmps is probably ParkDescentTime ( 67.0% )
#  or ConnectTimeOut ( 56.00000000000001% )
#  or IceEvasionP ( 55.00000000000001% )
#
# QuiescentVolts is probably ParkDescentTime ( 61.0% )
#  or AscentTimeOut ( 57.99999999999999% )
#  or FullRetraction ( 56.99999999999999% )
#
# QuiescentVolts is probably IceDetectionP ( 60.0% )
#  or ConnectTimeOut ( 56.99999999999999% )
#  or IceEvasionP ( 55.00000000000001% )
#
# RtcSkew is probably IceMonths ( 50.0% )
#  or PnPCycleLen ( 49.0% )
#  or IceEvasionP ( 49.0% )
#
# Sbe41cpAmps is probably OkVacuum ( 48.0% )
#  or DeepProfilePistonPos ( 47.0% )
#  or DeepProfileDescentTime ( 47.0% )
#
# Sbe41cpAmps is probably ConnectTimeOut ( 50.0% )
#  or TelemetryRetry ( 44.0% )
#  or IceMonths ( 42.0% )
#
# Sbe41cpVolts is probably DeepProfileDescentTime ( 55.00000000000001% )
#  or DeepProfilePistonPos ( 54.0% )
#  or Verbosity ( 51.0% )
#
# Sbe41cpVolts is probably IceMonths ( 59.0% )
#  or FullRetraction ( 48.0% )
#  or TimeOfDay ( 46.0% )
#
# Sbe41cpStatus is probably PActivationPistonPosition ( 53.0% )
#  or CpActivationP ( 52.0% )
#  or ConnectTimeOut ( 51.0% )
#
# SurfacePistonPosition is probably ParkPistonPos ( 76.0% )
#  or PActivationPistonPosition ( 67.0% )
#  or DeepProfilePistonPos ( 63.0% )
#
# SurfacePistonPosition is probably IceEvasionP ( 56.00000000000001% )
#  or IceDetectionP ( 53.0% )
#  or AscentTimeOut ( 52.0% )
#
# SurfacePressure is probably ParkDescentTime ( 57.99999999999999% )
#  or IceMonths ( 51.0% )
#  or BuoyancyNudge ( 51.0% )
#
# Vacuum is probably OkVacuum ( 92.0% )
#  or AtDialCmd ( 52.0% )
#  or nan ( 50.0% )
#
# Vacuum is probably nan ( 50.0% )
#  or nan ( 50.0% )
#  or FullExtension ( 46.0% )
#
# Fix:  170.174  38.652 06/26/2017 001700    9 is probably FlashErase ( 44.0% )
#  or FlashCreate ( 43.0% )
#  or MaxLogKb ( 38.0% )
#
# Apf9iFwRev is probably UpTime ( 60.0% )
#  or AirBladderMaxP ( 55.00000000000001% )
#  or DeepProfilePistonPos ( 53.0% )
#
# ActiveBallastAdjustments is probably AirBladderMaxP ( 57.99999999999999% )
#  or AscentTimeOut ( 54.0% )
#  or AtDialCmd ( 53.0% )
#
# ActiveBallastAdjustments is probably AltDialCmd ( 66.0% )
#  or AtDialCmd ( 63.0% )
#  or CpActivationP ( 61.0% )
#
# AirBladderPressure is probably AirBladderMaxP ( 100.0% )
#  or AscentTimeOut ( 54.0% )
#  or MissionPrelude ( 53.0% )
#
# AirBladderPressure is probably AtDialCmd ( 59.0% )
#  or AltDialCmd ( 56.99999999999999% )
#  or AscentTimeOut ( 55.00000000000001% )
#
# AirPumpAmps is probably AirBladderMaxP ( 65.0% )
#  or AtDialCmd ( 57.99999999999999% )
#  or AltDialCmd ( 56.99999999999999% )
#
# AirPumpVolts is probably AirBladderMaxP ( 68.0% )
#  or DeepProfilePistonPos ( 55.00000000000001% )
#  or ParkPistonPos ( 54.0% )
#
# AirPumpVolts is probably AtDialCmd ( 56.00000000000001% )
#  or AltDialCmd ( 55.00000000000001% )
#  or IceMonths ( 53.0% )
#
# BuoyancyPumpOnTime is probably BuoyancyNudge ( 95.0% )
#  or BuoyancyNudgeInitial ( 94.0% )
#  or MissionPrelude ( 54.0% )
#
# BuoyancyPumpOnTime is probably ConnectTimeOut ( 60.0% )
#  or OkVacuum ( 55.00000000000001% )
#  or DownTime ( 52.0% )
#
# BuoyancyPumpAmps is probably BuoyancyNudge ( 95.0% )
#  or BuoyancyNudgeInitial ( 93.0% )
#  or MissionPrelude ( 51.0% )
#
# BuoyancyPumpVolts is probably BuoyancyNudge ( 95.0% )
#  or BuoyancyNudgeInitial ( 94.0% )
#  or OkVacuum ( 54.0% )
#
# IceEvasionRecord is probably ParkPistonPos ( 56.00000000000001% )
#  or ConnectTimeOut ( 54.0% )
#  or IceEvasionP ( 48.0% )
#
# IceEvasionRecord is probably IceEvasionP ( 100.0% )
#  or IceDetectionP ( 72.0% )
#  or IceMLTCritical ( 72.0% )
#
# IceMLMedianT is probably PnPCycleLen ( 62.0% )
#  or AscentTimeOut ( 54.0% )
#  or DeepProfilePistonPos ( 51.0% )
#
# IceMLMedianT is probably IceMLTCritical ( 84.0% )
#  or IceMonths ( 79.0% )
#  or IceDetectionP ( 76.0% )
#
# IceMLSample is probably IceMLTCritical ( 86.0% )
#  or IceEvasionP ( 70.0% )
#  or IceDetectionP ( 69.0% )
#
# IceMLSample is probably IceMonths ( 76.0% )
#  or ParkPistonPos ( 63.0% )
#  or DeepProfilePistonPos ( 62.0% )
#
# CurrentPistonPosition is probably PActivationPistonPosition ( 65.0% )
#  or CpActivationP ( 56.99999999999999% )
#  or ConnectTimeOut ( 56.00000000000001% )
#
# DeepProfilePistonPosition is probably DeepProfileDescentTime ( 100.0% )
#  or DeepProfilePistonPos ( 100.0% )
#  or ParkPistonPos ( 66.0% )
#
# GpsFixTime is probably AscentTimeOut ( 56.00000000000001% )
#  or DownTime ( 55.00000000000001% )
#  or IceDetectionP ( 54.0% )
#
# GpsFixTime is probably CpActivationP ( 51.0% )
#  or MissionPrelude ( 48.0% )
#  or Verbosity ( 47.0% )
#
# FlashErrorsCorrectable is probably FullRetraction ( 54.0% )
#  or FullExtension ( 52.0% )
#  or ParkDescentTime ( 50.0% )
#
# FlashErrorsCorrectable is probably FlashErase ( 92.0% )
#  or FlashCreate ( 83.0% )
#  or FullRetraction ( 53.0% )
#
# FlashErrorsUncorrectable is probably FlashErase ( 91.0% )
#  or FlashCreate ( 80.0% )
#  or BuoyancyNudgeInitial ( 54.0% )
#
# FloatId is probably FullExtension ( 60.0% )
#  or FullRetraction ( 59.0% )
#  or AtDialCmd ( 59.0% )
#
# ParkDescentPCnt is probably ParkPistonPos ( 79.0% )
#  or FlashErase ( 66.0% )
#  or FlashCreate ( 65.0% )
#
# ParkDescentPCnt is probably ParkDescentTime ( 100.0% )
#  or IceDetectionP ( 59.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#
# ParkDescentP[0] is probably ParkDescentTime ( 100.0% )
#  or ParkPistonPos ( 79.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#
# ParkDescentP[1] is probably ParkPistonPos ( 79.0% )
#  or IceDetectionP ( 56.99999999999999% )
#  or IceEvasionP ( 56.99999999999999% )
#
# ParkDescentP[1] is probably ParkDescentTime ( 100.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#  or IceDetectionP ( 56.99999999999999% )
#
# ParkDescentP[2] is probably ParkDescentTime ( 100.0% )
#  or ParkPistonPos ( 79.0% )
#  or DeepProfileDescentTime ( 54.0% )
#
# ParkDescentP[2] is probably PnPCycleLen ( 57.99999999999999% )
#  or IceDetectionP ( 56.99999999999999% )
#  or IceEvasionP ( 56.99999999999999% )
#
# ParkDescentP[3] is probably ParkDescentTime ( 100.0% )
#  or ParkPistonPos ( 79.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#
# ParkDescentP[4] is probably ParkPistonPos ( 79.0% )
#  or IceDetectionP ( 56.99999999999999% )
#  or IceEvasionP ( 56.99999999999999% )
#
# ParkDescentP[4] is probably ParkDescentTime ( 100.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#  or IceDetectionP ( 56.99999999999999% )
#
# ParkDescentP[5] is probably ParkDescentTime ( 100.0% )
#  or ParkPistonPos ( 79.0% )
#  or PnPCycleLen ( 57.99999999999999% )
#
# ParkPistonPosition is probably ParkPistonPos ( 100.0% )
#  or DeepProfilePistonPos ( 66.0% )
#  or IceDetectionP ( 56.99999999999999% )
#
# ParkPistonPosition is probably ParkDescentTime ( 76.0% )
#  or PActivationPistonPosition ( 75.0% )
#  or CpActivationP ( 54.0% )
#
# ParkObs is probably ParkPistonPos ( 82.0% )
#  or ParkDescentTime ( 81.0% )
#  or Verbosity ( 59.0% )
#
# ProfileId is probably DownTime ( 56.99999999999999% )
#  or ParkPistonPos ( 56.99999999999999% )
#  or DeepProfilePistonPos ( 54.0% )
#
# ProfileId is probably PnPCycleLen ( 57.99999999999999% )
#  or ParkDescentTime ( 56.00000000000001% )
#  or AtDialCmd ( 56.00000000000001% )
#
# ObsIndex is probably MissionPrelude ( 53.0% )
#  or DownTime ( 50.0% )
#  or nan ( 49.0% )
#
# QuiescentAmps is probably AscentTimeOut ( 57.99999999999999% )
#  or UpTime ( 50.0% )
#  or Verbosity ( 49.0% )
#
# QuiescentAmps is probably ParkDescentTime ( 67.0% )
#  or ConnectTimeOut ( 56.00000000000001% )
#  or ParkPistonPos ( 52.0% )
#
# QuiescentVolts is probably ParkDescentTime ( 61.0% )
#  or AscentTimeOut ( 57.99999999999999% )
#  or FullRetraction ( 56.99999999999999% )
#
# QuiescentVolts is probably IceDetectionP ( 60.0% )
#  or ConnectTimeOut ( 56.99999999999999% )
#  or IceEvasionP ( 55.00000000000001% )
#
# RtcSkew is probably PnPCycleLen ( 49.0% )
#  or FullRetraction ( 48.0% )
#  or ParkDescentTime ( 47.0% )
#
# RtcSkew is probably IceMonths ( 50.0% )
#  or IceEvasionP ( 49.0% )
#  or OkVacuum ( 48.0% )
#
# Sbe41cpAmps is probably ConnectTimeOut ( 50.0% )
#  or DeepProfileDescentTime ( 47.0% )
#  or TelemetryRetry ( 44.0% )
#
# Sbe41cpVolts is probably DeepProfileDescentTime ( 55.00000000000001% )
#  or DeepProfilePistonPos ( 54.0% )
#  or Verbosity ( 51.0% )
#
# Sbe41cpVolts is probably IceMonths ( 59.0% )
#  or ConnectTimeOut ( 49.0% )
#  or AscentTimeOut ( 46.0% )
#
# Sbe41cpStatus is probably PActivationPistonPosition ( 53.0% )
#  or CpActivationP ( 52.0% )
#  or ConnectTimeOut ( 51.0% )
#
# SurfacePistonPosition is probably ParkPistonPos ( 76.0% )
#  or PActivationPistonPosition ( 67.0% )
#  or DeepProfilePistonPos ( 63.0% )
#
# SurfacePistonPosition is probably IceEvasionP ( 56.00000000000001% )
#  or CpActivationP ( 54.0% )
#  or IceDetectionP ( 53.0% )
#
# SurfacePressure is probably ParkDescentTime ( 57.99999999999999% )
#  or BuoyancyNudge ( 51.0% )
#  or AirBladderMaxP ( 50.0% )
#
# Vacuum is probably OkVacuum ( 92.0% )
#  or IceMonths ( 51.0% )
#  or nan ( 50.0% )

# %% [markdown]
# #### msgファイルと技術情報タブの比較

# %%
# 結果保存用のDFを準備
msgtechdf = pd.DataFrame(columns=['index','msg','xls','score'])

for line in logdata.values():
    #print(line)
    query = tech['a26msg'].str.startswith(line , na=False)
    #print(query.values)
    if (query[query == True].first_valid_index()):
        print( termcolor.colored( line + ' field exists.' , 'blue'))
    else:
        print( termcolor.colored( line + ' is not found.' , 'red'))
        
        for index,item in tech.iterrows():
            score = jaro_dist(str(item['a26msg']) , line) # 引数を入れ替えると結果が多少変わる。
            #print(line + ' is probably ' + str(item['i4']) + ' ( ' + str(round(score,2)*100) + '%)' )
            rec_score = pd.Series([index , line , item['a26msg'] , score] , index=msgtechdf.columns)
            msgtechdf = msgtechdf.append(rec_score , ignore_index=True)
# Out:
# TelemetryInit is not found.
# AirSystem is not found.
# GpsServices is not found.
# GpsServices is not found.
# gga is not found.
# gga is not found.
# GpsServices is not found.
# GpsServices is not found.
# GpsServices is not found.
# gga is not found.
# gga is not found.
# GpsServices is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# GpsServices is not found.
# CLogin is not found.
# CLogin is not found.
# login is not found.
# CLogin is not found.
# RxConfig is not found.
# Rx is not found.
# RxStartByte is not found.
# Rx is not found.
# Rx is not found.
# RxConfig is not found.
# WriteVitals is not found.
# UpLoadFile is not found.
# Tx is not found.
# TxPacket is not found.
# TxPacket is not found.
# Tx is not found.
# UpLoadFile is not found.
# UpLoadFile is not found.
# Tx is not found.
# Tx is not found.
# UpLoadFile is not found.
# UpLoad is not found.
# UpLoad is not found.
# logout is not found.
# Telemetry is not found.
# DescentInit is not found.
# DescentInit is not found.
# PistonMoveAbsWTO is not found.
# Descent is not found.
# Descent is not found.
# Descent is not found.
# Descent is not found.
# Descent is not found.
# Descent is not found.
# ParkInit is not found.
# CtdPower is not found.
# CtdPower is not found.
# ParkTerminate is not found.
# ParkTerminate is not found.
# GoDeepInit is not found.
# PistonMoveAbsWTO is not found.
# GoDeep is not found.
# ProfileInit is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# Profile is not found.
# Sbe41cpStartCP is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# SurfaceDetect is not found.
# Sbe41cpStopCP is not found.
# PistonMoveAbsWTO is not found.
# sbe41cp.c:chat is not found.
# Sbe41cpBinAverage is not found.
# Sbe41cpUploadCP is not found.
# Sbe41cpUploadCP is not found.
#  field exists.
# > is not found.

# %% [markdown]
# ## ソートして上位3件表示

# %%
# スコアの結果DF（上ではdiff_resultをソートして上から3つを表示
techlength = len(tech) # Index数、この数分ジャロ・ウインクラー距離を計算したら次のマッチしなかった語句になる
num = int( len(msgtechdf) / techlength ) # クエリーのリストになくnot foundで表示した数

for count in range(num):
    sort_df = msgtechdf[techlength*count : techlength*(count+1)]
    sort_rank = sort_df.sort_values('score',ascending=False)[:3] # Score降順にソートして上から3つを表示
    
    #print(diff_result)
    if((re.match('^.',sort_rank.iat[0,1])) is not None  ):
        #print(diff_ranking.iat[0,3])
        # score が０と１の時は抜く（アルゴリズム？で１００％が結構出てる。
        disp_rank2 = str(sort_rank.iat[0,1]) + ' is probably ' + str(sort_rank.iat[0,2]) + ' ( ' + str(round(sort_rank.iat[0,3] , 2) * 100 ) + '% )' + '\n' \
        + ' or ' + str(sort_rank.iat[1,2]) + ' ( ' + str(round(sort_rank.iat[1,3] , 2) * 100 ) + '% )' + '\n' \
        + ' or ' + str(sort_rank.iat[2,2]) + ' ( ' + str(round(sort_rank.iat[2,3] , 2) * 100 ) + '% )' + '\n' 
    
        print( disp_rank2 )
# Out:
# TelemetryInit is probably QuiescentAmps ( 52.0% )
#  or QuiescentVolts ( 51.0% )
#  or IceMLSample ( 50.0% )
#
# AirSystem is probably AirPumpAmps ( 72.0% )
#  or AirPumpVolts ( 71.0% )
#  or AirBladderPressure ( 69.0% )
#
# GpsServices is probably GpsFixTime ( 71.0% )
#  or QuiescentAmps ( 61.0% )
#  or QuiescentVolts ( 60.0% )
#
# GpsServices is probably GpsFixTime ( 71.0% )
#  or QuiescentAmps ( 61.0% )
#  or QuiescentVolts ( 60.0% )
#
# gga is probably nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#
# gga is probably nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#
# GpsServices is probably GpsFixTime ( 71.0% )
#  or QuiescentAmps ( 61.0% )
#  or QuiescentVolts ( 60.0% )
#
# GpsServices is probably GpsFixTime ( 71.0% )
#  or QuiescentAmps ( 61.0% )
#  or QuiescentVolts ( 60.0% )
#
# GpsServices is probably GpsFixTime ( 71.0% )
#  or QuiescentAmps ( 61.0% )
#  or QuiescentVolts ( 60.0% )
#
# gga is probably nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#
# gga is probably nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#
# GpsServices is probably GpsFixTime ( 71.0% )
#  or QuiescentAmps ( 61.0% )
#  or QuiescentVolts ( 60.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# GpsServices is probably GpsFixTime ( 71.0% )
#  or QuiescentAmps ( 61.0% )
#  or QuiescentVolts ( 60.0% )
#
# CLogin is probably CurrentPistonPosition ( 53.0% )
#  or msg ( 50.0% )
#  or QuiescentAmps ( 50.0% )
#
# CLogin is probably CurrentPistonPosition ( 53.0% )
#  or msg ( 50.0% )
#  or QuiescentAmps ( 50.0% )
#
# login is probably QuiescentAmps ( 52.0% )
#  or QuiescentVolts ( 51.0% )
#  or nan ( 51.0% )
#
# CLogin is probably CurrentPistonPosition ( 53.0% )
#  or msg ( 50.0% )
#  or QuiescentAmps ( 50.0% )
#
# RxConfig is probably CurrentPistonPosition ( 51.0% )
#  or DeepProfilePistonPosition ( 50.0% )
#  or nan ( 49.0% )
#
# Rx is probably RtcSkew ( 59.0% )
#  or nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#
# RxStartByte is probably status ( 59.0% )
#  or Sbe41cpStatus ( 56.00000000000001% )
#  or IceMLSample ( 52.0% )
#
# Rx is probably RtcSkew ( 59.0% )
#  or nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#
# Rx is probably RtcSkew ( 59.0% )
#  or nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#
# RxConfig is probably CurrentPistonPosition ( 51.0% )
#  or DeepProfilePistonPosition ( 50.0% )
#  or nan ( 49.0% )
#
# WriteVitals is probably QuiescentVolts ( 59.0% )
#  or AirPumpVolts ( 56.99999999999999% )
#  or Sbe41cpVolts ( 56.00000000000001% )
#
# UpLoadFile is probably GpsFixTime ( 60.0% )
#  or IceMLSample ( 59.0% )
#  or IceMLMedianT ( 56.99999999999999% )
#
# Tx is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
#
# TxPacket is probably RtcSkew ( 60.0% )
#  or ParkPistonPosition ( 56.99999999999999% )
#  or SurfacePistonPosition ( 56.00000000000001% )
#
# TxPacket is probably RtcSkew ( 60.0% )
#  or ParkPistonPosition ( 56.99999999999999% )
#  or SurfacePistonPosition ( 56.00000000000001% )
#
# Tx is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
#
# UpLoadFile is probably GpsFixTime ( 60.0% )
#  or IceMLSample ( 59.0% )
#  or IceMLMedianT ( 56.99999999999999% )
#
# UpLoadFile is probably GpsFixTime ( 60.0% )
#  or IceMLSample ( 59.0% )
#  or IceMLMedianT ( 56.99999999999999% )
#
# Tx is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
#
# Tx is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
#
# UpLoadFile is probably GpsFixTime ( 60.0% )
#  or IceMLSample ( 59.0% )
#  or IceMLMedianT ( 56.99999999999999% )
#
# UpLoad is probably IceMLSample ( 51.0% )
#  or IceMLMedianT ( 50.0% )
#  or BuoyancyPumpAmps ( 49.0% )
#
# UpLoad is probably IceMLSample ( 51.0% )
#  or IceMLMedianT ( 50.0% )
#  or BuoyancyPumpAmps ( 49.0% )
#
# logout is probably msg ( 50.0% )
#  or QuiescentAmps ( 50.0% )
#  or QuiescentVolts ( 49.0% )
#
# Telemetry is probably IceMLSample ( 54.0% )
#  or QuiescentAmps ( 52.0% )
#  or QuiescentVolts ( 52.0% )
#
# DescentInit is probably QuiescentVolts ( 71.0% )
#  or QuiescentAmps ( 67.0% )
#  or DeepProfilePistonPosition ( 64.0% )
#
# DescentInit is probably QuiescentVolts ( 71.0% )
#  or QuiescentAmps ( 67.0% )
#  or DeepProfilePistonPosition ( 64.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# Descent is probably QuiescentAmps ( 77.0% )
#  or QuiescentVolts ( 76.0% )
#  or DeepProfilePistonPosition ( 61.0% )
#
# Descent is probably QuiescentAmps ( 77.0% )
#  or QuiescentVolts ( 76.0% )
#  or DeepProfilePistonPosition ( 61.0% )
#
# Descent is probably QuiescentAmps ( 77.0% )
#  or QuiescentVolts ( 76.0% )
#  or DeepProfilePistonPosition ( 61.0% )
#
# Descent is probably QuiescentAmps ( 77.0% )
#  or QuiescentVolts ( 76.0% )
#  or DeepProfilePistonPosition ( 61.0% )
#
# Descent is probably QuiescentAmps ( 77.0% )
#  or QuiescentVolts ( 76.0% )
#  or DeepProfilePistonPosition ( 61.0% )
#
# Descent is probably QuiescentAmps ( 77.0% )
#  or QuiescentVolts ( 76.0% )
#  or DeepProfilePistonPosition ( 61.0% )
#
# ParkInit is probably ParkPistonPosition ( 81.0% )
#  or ObsIndex ( 50.0% )
#  or DeepProfilePistonPosition ( 50.0% )
#
# CtdPower is probably CurrentPistonPosition ( 53.0% )
#  or AirBladderPressure ( 51.0% )
#  or ObsIndex ( 50.0% )
#
# CtdPower is probably CurrentPistonPosition ( 53.0% )
#  or AirBladderPressure ( 51.0% )
#  or ObsIndex ( 50.0% )
#
# ParkTerminate is probably ParkPistonPosition ( 76.0% )
#  or FlashErrorsUncorrectable ( 53.0% )
#  or FlashErrorsUncorrectable ( 53.0% )
#
# ParkTerminate is probably ParkPistonPosition ( 76.0% )
#  or FlashErrorsUncorrectable ( 53.0% )
#  or FlashErrorsUncorrectable ( 53.0% )
#
# GoDeepInit is probably QuiescentAmps ( 56.99999999999999% )
#  or QuiescentVolts ( 56.00000000000001% )
#  or DeepProfilePistonPosition ( 54.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# GoDeep is probably DeepProfilePistonPosition ( 61.0% )
#  or IceMLSample ( 51.0% )
#  or Sbe41cpAmps ( 51.0% )
#
# ProfileInit is probably ParkPistonPosition ( 60.0% )
#  or AirPumpVolts ( 60.0% )
#  or DeepProfilePistonPosition ( 60.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# Profile is probably DeepProfilePistonPosition ( 59.0% )
#  or ParkPistonPosition ( 57.99999999999999% )
#  or AirPumpVolts ( 55.00000000000001% )
#
# Sbe41cpStartCP is probably Sbe41cpStatus ( 100.0% )
#  or Sbe41cpVolts ( 92.0% )
#  or Sbe41cpAmps ( 91.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# SurfaceDetect is probably SurfacePistonPosition ( 91.0% )
#  or Sbe41cpStatus ( 60.0% )
#  or QuiescentVolts ( 56.99999999999999% )
#
# Sbe41cpStopCP is probably Sbe41cpStatus ( 98.0% )
#  or Sbe41cpAmps ( 93.0% )
#  or Sbe41cpVolts ( 93.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# sbe41cp.c:chat is probably Sbe41cpVolts ( 69.0% )
#  or Sbe41cpStatus ( 69.0% )
#  or Sbe41cpAmps ( 66.0% )
#
# Sbe41cpBinAverage is probably Sbe41cpAmps ( 92.0% )
#  or Sbe41cpStatus ( 91.0% )
#  or Sbe41cpVolts ( 90.0% )
#
# Sbe41cpUploadCP is probably Sbe41cpAmps ( 93.0% )
#  or Sbe41cpVolts ( 92.0% )
#  or Sbe41cpStatus ( 91.0% )
#
# Sbe41cpUploadCP is probably Sbe41cpAmps ( 93.0% )
#  or Sbe41cpVolts ( 92.0% )
#  or Sbe41cpStatus ( 91.0% )
#
# > is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )

# %% [markdown]
# #### logファイルと技術情報の比較

# %%
# 結果保存用のDFを準備
logtechdf = pd.DataFrame(columns=['index','msg','xls','score'])

for line in logdata.values():
    #print(line)
    query = tech['a26log'].str.startswith(line , na=False)
    #print(query.values)
    if (query[query == True].first_valid_index()):
        print( termcolor.colored( line + ' field exists.' , 'blue'))
    else:
        print( termcolor.colored( line + ' is not found.' , 'red'))
        
        for index,item in tech.iterrows():
            score = jaro_dist(str(item['a26msg']) , line) # 引数を入れ替えると結果が多少変わる。
            #print(line + ' is probably ' + str(item['i4']) + ' ( ' + str(round(score,2)*100) + '%)' )
            rec_score = pd.Series([index , line , item['a26msg'] , score] , index=logtechdf.columns)
            logtechdf = logtechdf.append(rec_score , ignore_index=True)
# Out:
# TelemetryInit field exists.
# AirSystem is not found.
# GpsServices field exists.
# GpsServices field exists.
# gga is not found.
# gga is not found.
# GpsServices field exists.
# GpsServices field exists.
# GpsServices field exists.
# gga is not found.
# gga is not found.
# GpsServices field exists.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# LogNmeaSentences is not found.
# GpsServices field exists.
# CLogin is not found.
# CLogin is not found.
# login is not found.
# CLogin is not found.
# RxConfig is not found.
# Rx is not found.
# RxStartByte is not found.
# Rx is not found.
# Rx is not found.
# RxConfig is not found.
# WriteVitals is not found.
# UpLoadFile is not found.
# Tx is not found.
# TxPacket is not found.
# TxPacket is not found.
# Tx is not found.
# UpLoadFile is not found.
# UpLoadFile is not found.
# Tx is not found.
# Tx is not found.
# UpLoadFile is not found.
# UpLoad is not found.
# UpLoad is not found.
# logout field exists.
# Telemetry field exists.
# DescentInit field exists.
# DescentInit field exists.
# PistonMoveAbsWTO is not found.
# Descent field exists.
# Descent field exists.
# Descent field exists.
# Descent field exists.
# Descent field exists.
# Descent field exists.
# ParkInit field exists.
# CtdPower is not found.
# CtdPower is not found.
# ParkTerminate field exists.
# ParkTerminate field exists.
# GoDeepInit is not found.
# PistonMoveAbsWTO is not found.
# GoDeep is not found.
# ProfileInit field exists.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# Profile field exists.
# Sbe41cpStartCP field exists.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# AscentControlAgent is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# PistonMoveAbsWTO is not found.
# SurfaceDetect is not found.
# Sbe41cpStopCP is not found.
# PistonMoveAbsWTO is not found.
# sbe41cp.c:chat is not found.
# Sbe41cpBinAverage is not found.
# Sbe41cpUploadCP is not found.
# Sbe41cpUploadCP is not found.
#  field exists.
# > is not found.

# %% [markdown]
# ## ソートして上位３つを表示

# %%
# スコアの結果DF（上ではdiff_resultをソートして上から3つを表示
techlength = len(tech) # Index数、この数分ジャロ・ウインクラー距離を計算したら次のマッチしなかった語句になる
num = int( len(logtechdf) / techlength ) # クエリーのリストになくnot foundで表示した数

for count in range(num):
    sort_tdf = logtechdf[techlength*count : techlength*(count+1)]
    sort_trank = sort_tdf.sort_values('score',ascending=False)[:3] # Score降順にソートして上から3つを表示
    
    #print(diff_result)
    if((re.match('^.',sort_trank.iat[0,1])) is not None  ):
        #print(diff_ranking.iat[0,3])
        # score が０と１の時は抜く（アルゴリズム？で１００％が結構出てる。
        disp_rank3 = str(sort_trank.iat[0,1]) + ' is probably ' + str(sort_trank.iat[0,2]) + ' ( ' + str(round(sort_trank.iat[0,3] , 2) * 100 ) + '% )' + '\n' \
        + ' or ' + str(sort_trank.iat[1,2]) + ' ( ' + str(round(sort_trank.iat[1,3] , 2) * 100 ) + '% )' + '\n' \
        + ' or ' + str(sort_trank.iat[2,2]) + ' ( ' + str(round(sort_trank.iat[2,3] , 2) * 100 ) + '% )' + '\n' 
    
        print( disp_rank3 )
# Out:
# AirSystem is probably AirPumpAmps ( 72.0% )
#  or AirPumpVolts ( 71.0% )
#  or AirBladderPressure ( 69.0% )
#
# gga is probably nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#
# gga is probably nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#
# gga is probably nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#
# gga is probably nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#  or nan ( 56.00000000000001% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# LogNmeaSentences is probably QuiescentVolts ( 56.00000000000001% )
#  or IceMLSample ( 53.0% )
#  or BuoyancyPumpOnTime ( 49.0% )
#
# CLogin is probably CurrentPistonPosition ( 53.0% )
#  or msg ( 50.0% )
#  or QuiescentAmps ( 50.0% )
#
# CLogin is probably CurrentPistonPosition ( 53.0% )
#  or msg ( 50.0% )
#  or QuiescentAmps ( 50.0% )
#
# login is probably QuiescentAmps ( 52.0% )
#  or QuiescentVolts ( 51.0% )
#  or nan ( 51.0% )
#
# CLogin is probably CurrentPistonPosition ( 53.0% )
#  or msg ( 50.0% )
#  or QuiescentAmps ( 50.0% )
#
# RxConfig is probably CurrentPistonPosition ( 51.0% )
#  or DeepProfilePistonPosition ( 50.0% )
#  or nan ( 49.0% )
#
# Rx is probably RtcSkew ( 59.0% )
#  or nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#
# RxStartByte is probably status ( 59.0% )
#  or Sbe41cpStatus ( 56.00000000000001% )
#  or IceMLSample ( 52.0% )
#
# Rx is probably RtcSkew ( 59.0% )
#  or nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#
# Rx is probably RtcSkew ( 59.0% )
#  or nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#
# RxConfig is probably CurrentPistonPosition ( 51.0% )
#  or DeepProfilePistonPosition ( 50.0% )
#  or nan ( 49.0% )
#
# WriteVitals is probably QuiescentVolts ( 59.0% )
#  or AirPumpVolts ( 56.99999999999999% )
#  or Sbe41cpVolts ( 56.00000000000001% )
#
# UpLoadFile is probably GpsFixTime ( 60.0% )
#  or IceMLSample ( 59.0% )
#  or IceMLMedianT ( 56.99999999999999% )
#
# Tx is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
#
# TxPacket is probably RtcSkew ( 60.0% )
#  or ParkPistonPosition ( 56.99999999999999% )
#  or SurfacePistonPosition ( 56.00000000000001% )
#
# TxPacket is probably RtcSkew ( 60.0% )
#  or ParkPistonPosition ( 56.99999999999999% )
#  or SurfacePistonPosition ( 56.00000000000001% )
#
# Tx is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
#
# UpLoadFile is probably GpsFixTime ( 60.0% )
#  or IceMLSample ( 59.0% )
#  or IceMLMedianT ( 56.99999999999999% )
#
# UpLoadFile is probably GpsFixTime ( 60.0% )
#  or IceMLSample ( 59.0% )
#  or IceMLMedianT ( 56.99999999999999% )
#
# Tx is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
#
# Tx is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
#
# UpLoadFile is probably GpsFixTime ( 60.0% )
#  or IceMLSample ( 59.0% )
#  or IceMLMedianT ( 56.99999999999999% )
#
# UpLoad is probably IceMLSample ( 51.0% )
#  or IceMLMedianT ( 50.0% )
#  or BuoyancyPumpAmps ( 49.0% )
#
# UpLoad is probably IceMLSample ( 51.0% )
#  or IceMLMedianT ( 50.0% )
#  or BuoyancyPumpAmps ( 49.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# CtdPower is probably CurrentPistonPosition ( 53.0% )
#  or AirBladderPressure ( 51.0% )
#  or ObsIndex ( 50.0% )
#
# CtdPower is probably CurrentPistonPosition ( 53.0% )
#  or AirBladderPressure ( 51.0% )
#  or ObsIndex ( 50.0% )
#
# GoDeepInit is probably QuiescentAmps ( 56.99999999999999% )
#  or QuiescentVolts ( 56.00000000000001% )
#  or DeepProfilePistonPosition ( 54.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# GoDeep is probably DeepProfilePistonPosition ( 61.0% )
#  or IceMLSample ( 51.0% )
#  or Sbe41cpAmps ( 51.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# AscentControlAgent is probably SurfacePistonPosition ( 59.0% )
#  or CurrentPistonPosition ( 59.0% )
#  or ActiveBallastAdjustments ( 59.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# SurfaceDetect is probably SurfacePistonPosition ( 91.0% )
#  or Sbe41cpStatus ( 60.0% )
#  or QuiescentVolts ( 56.99999999999999% )
#
# Sbe41cpStopCP is probably Sbe41cpStatus ( 98.0% )
#  or Sbe41cpAmps ( 93.0% )
#  or Sbe41cpVolts ( 93.0% )
#
# PistonMoveAbsWTO is probably ParkPistonPosition ( 68.0% )
#  or QuiescentAmps ( 59.0% )
#  or QuiescentVolts ( 53.0% )
#
# sbe41cp.c:chat is probably Sbe41cpVolts ( 69.0% )
#  or Sbe41cpStatus ( 69.0% )
#  or Sbe41cpAmps ( 66.0% )
#
# Sbe41cpBinAverage is probably Sbe41cpAmps ( 92.0% )
#  or Sbe41cpStatus ( 91.0% )
#  or Sbe41cpVolts ( 90.0% )
#
# Sbe41cpUploadCP is probably Sbe41cpAmps ( 93.0% )
#  or Sbe41cpVolts ( 92.0% )
#  or Sbe41cpStatus ( 91.0% )
#
# Sbe41cpUploadCP is probably Sbe41cpAmps ( 93.0% )
#  or Sbe41cpVolts ( 92.0% )
#  or Sbe41cpStatus ( 91.0% )
#
# > is probably nan ( 0.0% )
#  or IceMLSample ( 0.0% )
#  or FlashErrorsCorrectable ( 0.0% )
